# %% [markdown]
# # Week 1 Exploration Notebook
#
# This notebook is used to test loading PurpleAir data and verifying the Python environment.

# %%
import pandas as pd
import matplotlib.pyplot as plt

print('Notebook initialized successfully!')
